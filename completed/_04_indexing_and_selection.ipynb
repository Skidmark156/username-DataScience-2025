# %% [markdown]
# <a href="https://colab.research.google.com/github/Skidmark156/username-DataScience-2025/blob/main/completed/_04_indexing_and_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🎯 Notebook 04: Indexing and Selection
#
# Time to slice and dice.
#
# In this notebook, you'll:
# - Use `.loc[]` for label-based selection
# - Use `.iloc[]` for position-based selection
# - Create boolean masks to filter rows
# - Select specific columns and rows (solo or together)
#
# Let the chaos of index manipulation begin.
# ---

# %%
import pandas as pd
import seaborn as sns

# We'll use the Titanic dataset again
df = sns.load_dataset("titanic")
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %% [markdown]
# ## 🔎 Select rows by label with `.loc[]`

# %%
# .loc[row_label, column_label]
# Titanic uses default RangeIndex, so labels are integers
print(df.loc[0])

# Row range (inclusive!)
df.loc[0:4, ["age", "fare", "sex"]]
# Out:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
#     age     fare     sex
# 0  22.0   7.2500    male
# 1  38.0  71.2833  female
# 2  26.0   7.9250  female
# 3  35.0  53.1000  female
# 4  35.0   8.0500    male

# %% [markdown]
# ## 🔢 Select rows by position with `.iloc[]`

# %%
# iloc uses pure positions
df.iloc[0]  # First row

# Row slice, column slice
df.iloc[1:4, 0:5]
# Out:
#    survived  pclass     sex   age  sibsp
# 1         1       1  female  38.0      1
# 2         1       3  female  26.0      0
# 3         1       1  female  35.0      1

# %% [markdown]
# ## 🎯 Boolean Masking (Filtering)

# %%
# Filter passengers under age 10
kids = df[df["age"] < 10]
kids[["age", "sex", "class"]].head()
# Out:
#     age     sex   class
# 7   2.0    male   Third
# 10  4.0  female   Third
# 16  2.0    male   Third
# 24  8.0  female   Third
# 43  3.0  female  Second

# %% [markdown]
# ## 🧠 Compound Conditions

# %%
# Adults in First Class who paid over $100
rich_folks = df[(df["age"] > 18) & (df["class"] == "First") & (df["fare"] > 100)]
rich_folks[["age", "class", "fare"]].head()
# Out:
#       age  class      fare
# 27   19.0  First  263.0000
# 88   23.0  First  263.0000
# 118  24.0  First  247.5208
# 195  58.0  First  146.5208
# 215  31.0  First  113.2750

# %% [markdown]
# ## 🧹 Select Columns Only

# %%
df[["sex", "age", "embarked"]].head()
# Out:
#       sex   age embarked
# 0    male  22.0        S
# 1  female  38.0        C
# 2  female  26.0        S
# 3  female  35.0        S
# 4    male  35.0        S

# %% [markdown]
# ## 🎯 Your Turn
#
# 1. Select the first row using `.iloc[]`, then again using `.loc[]`.
# 2. Slice the first 5 rows and select only `survived`, `sex`, and `age` columns.
# 3. Filter the dataset for female passengers over 40.
# 4. Create a DataFrame of passengers in 2nd class under age 15.
# 5. Use `.loc[]` to select the rows 10–20 and only the columns `fare`, `class`, and `age`.
#
# 🎯 **Bonus:** Find passengers with missing `age` and print only their `name`, `age`, and `pclass` (use `.isnull()`).

# %%
import pandas as pd
import seaborn as sns

# Load the Titanic dataset
df = sns.load_dataset("titanic")

# Select the first row using .iloc[], then again using .loc[]
print("First row using .iloc[]:")
print(df.iloc[0])

print("\nFirst row using .loc[]:")
print(df.loc[0])

# Slice the first 5 rows and select only survived, sex, and age columns
print("\nFirst 5 rows (survived, sex, age):")
print(df.loc[0:4, ["survived", "sex", "age"]])

# Filter the dataset for female passengers over 40
females_over_40 = df[(df["sex"] == "female") & (df["age"] > 40)]
print("\nFemale passengers over 40:")
print(females_over_40[["sex", "age", "class", "fare"]].head())

# Create a DataFrame of passengers in 2nd class under age 15
second_class_kids = df[(df["class"] == "Second") & (df["age"] < 15)]
print("\n2nd Class passengers under age 15:")
print(second_class_kids[["age", "class", "sex", "fare"]].head())

# Use .loc[] to select rows 10–20 and only the columns fare, class, and age
print("\nRows 10–20, columns fare/class/age:")
print(df.loc[10:20, ["fare", "class", "age"]])

# Bonus: Find passengers with missing age and print only their name, age, and pclass
missing_age = df[df["age"].isnull()]
print("\nPassengers with missing age:")
print(missing_age[["who", "age", "pclass"]].head())
# Out:
# First row using .iloc[]:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
#
# First row using .loc[]:
# survived                 0
# pclass                   3
# sex                   male
# age                   22.0
# sibsp                    1
# parch                    0
# fare                  7.25
# embarked                 S
# class                Third
# who                    man
# adult_male            True
# deck                   NaN
# embark_town    Southampton
# alive                   no
# alone                False
# Name: 0, dtype: object
#
# First 5 rows (survived, sex, age):
#    survived     sex   age
# 0         0    male  22.0
# 1         1  female  38.0
# 2         1  female  26.0
# 3         1  female  35.0
# 4         0    male  35.0
#
# Female passengers over 40:
#         sex   age   class     fare
# 11   female  58.0   First  26.5500
# 15   female  55.0  Second  16.0000
# 52   female  49.0   First  76.7292
# 132  female  47.0   Third  14.5000
# 167  female  45.0   Third  27.9000
#
# 2nd Class passengers under age 15:
#        age   class     sex     fare
# 9    14.00  Second  female  30.0708
# 43    3.00  Second  female  41.5792
# 58    5.00  Second  female  27.7500
# 78    0.83  Second    male  29.0000
# 183   1.00  Second    male  39.0000
#
# Rows 10–20, columns fare/class/age:
#        fare   class   age
# 10  16.7000   Third   4.0
# 11  26.5500   First  58.0
# 12   8.0500   Third  20.0
# 13  31.2750   Third  39.0
# 14   7.8542   Third  14.0
# 15  16.0000  Second  55.0
# 16  29.1250   Third   2.0
# 17  13.0000  Second   NaN
# 18  18.0000   Third  31.0
# 19   7.2250   Third   NaN
# 20  26.0000  Second  35.0
#
# Passengers with missing age:
#       who  age  pclass
# 5     man  NaN       3
# 17    man  NaN       2
# 19  woman  NaN       3
# 26    man  NaN       3
# 28  woman  NaN       3

# %% [markdown]
# ---
# ## 🧼 Why This Matters
#
# Being able to surgically select parts of your dataset is the core of real analysis. Whether you're cleaning junk or feeding a model, proper indexing = power.
#
# Next: cleaning your data with `.dropna()`, `.fillna()`, and more. The fun begins when you try to fix the stuff that's broken.
