# %% [markdown]
# <a href="https://colab.research.google.com/github/Skidmark156/username-DataScience-2025/blob/main/completed/01_Lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 01 - Python Lists
#
# Explore how to use lists to store and manipulate data.

# %% [markdown]
# ## ✅ Learning Goals
# - Create and modify Python lists
# - Access elements using indexing
# - Use list methods like `append()`, `remove()`, and `sort()`

# %%
# 🔧 Create a List
my_list = [10, 20, 30, 40, 50]
print(my_list)

# %%
# 🎯 Access Elements
print('First item:', my_list[0])
print('Last item:', my_list[-1])

# %%
# ➕ Modify List
my_list.append(60)
my_list.remove(30)
print(my_list)

# %%
# 🔁 Loop Through List
for item in my_list:
    print(item)

# %% [markdown]
# ## ✏️ Your Turn
# Create your own list of 5 favorite movies and sort them alphabetically.

# %%
# Favorite Movies List
favorite_movies = ["Inception", "The Dark Knight", "Superman", "Gladiator", "Clash Royale"]

# Sort the list alphabetically
favorite_movies.sort()

print("My Favorite Movies (A–Z):")
for movie in favorite_movies:
    print(movie)
