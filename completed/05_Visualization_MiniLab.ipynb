# %% [markdown]
# <a href="https://colab.research.google.com/github/Skidmark156/username-DataScience-2025/blob/main/completed/05_Visualization_MiniLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔬 Visualization Mini-Lab: Trends and Outliers
#
# Now it’s time to put your skills to the test!
# In this mini-lab, you’ll explore a real dataset, create visualizations, and identify **trends and outliers**.
#
# We’ll use the famous **Penguins dataset** (thanks to Seaborn).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
#penguins = sns.load_dataset("penguins")
penguins = pd.read_csv("../../data/penguins.csv")
penguins.head()

# %% [markdown]
# ## 1. Explore Distributions
#
# First, let’s look at the distribution of **body mass**.

# %%
sns.histplot(data=penguins, x="body_mass_g", kde=True, hue="species")
plt.title("Distribution of Body Mass by Species")
plt.show()

# %% [markdown]
# 👉 **Task:** Do some species have higher average body mass than others?

# %% [markdown]
# Yes Gentoo penguins tend to have a noticeably higher average body mass compared to Adelie and Chinstrap penguins. The histogram shows the Gentoo distribution shifted to the right.

# %% [markdown]
# ## 2. Relationships Between Variables
#
# Scatterplots help us see trends between two quantitative variables.

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g", hue="species")
plt.title("Flipper Length vs Body Mass")
plt.show()

# %% [markdown]
# 👉 **Task:** Which species tends to have longer flippers AND higher body mass?

# %% [markdown]
# Gentoo penguins again show the trend. They cluster in the upper-right corner, indicating both longer flippers and heavier body mass. Adelie penguins tend to be smaller with shorter flippers.

# %% [markdown]
# ## 3. Box Plots for Outliers
#
# Box plots are great for spotting outliers.

# %%
sns.boxplot(data=penguins, x="species", y="bill_length_mm", palette="Set2")
plt.title("Bill Length by Species")
plt.show()

# %% [markdown]
# 👉 **Task:** Can you spot any outliers in the bill length data?

# %% [markdown]
# Yes there are a few points outside the whiskers, which represent outliers. Penguins with unusually long or short bills for their species.

# %% [markdown]
# ## 4. Correlation Heatmap
#
# Correlation heatmaps let us see overall variable relationships.

# %%
corr = penguins.dropna().corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Flipper length and body mass show a strong positive correlation longer flippers are generally linked to heavier penguins. Bill length and bill depth have a moderate correlation, depending on species.

# %% [markdown]
# 👉 **Task:** Which variables appear to be strongly correlated?

# %% [markdown]
# ## 5. Your Turn
#
# - Try a different dataset (e.g., `tips`, `iris`).
# - Create **at least 2 plots** that reveal a trend.
# - Create **1 plot** that highlights possible outliers.
# - Write a short summary of your findings.
#
# > Remember: The goal is to **use visualizations to tell a story about the data.**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

tips = sns.load_dataset("tips")

# Trend 1: Relationship between total bill and tip
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
plt.title("Total Bill vs Tip Amount")
plt.show()

# Trend 2: Average tip by day
sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")
plt.title("Average Tip by Day")
plt.show()

# Outliers: Tip percentages
tips["tip_pct"] = tips["tip"] / tips["total_bill"] * 100
sns.boxplot(data=tips, x="day", y="tip_pct", palette="Set3")
plt.title("Tip Percentage by Day")
plt.show()
# Out:
# /tmp/ipython-input-1988280397.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")
# /tmp/ipython-input-1988280397.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", ci="sd", palette="muted")
# /tmp/ipython-input-1988280397.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x="day", y="tip_pct", palette="Set3")

# %% [markdown]
# ---
# ✅ Congratulations! You’ve completed the visualization mini-lab and Week 07.
#
# Next module → Working with larger datasets and diving deeper into analysis.
